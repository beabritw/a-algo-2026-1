# %%
import math

# %%
def F(n):
  """
  Function that calculates the value of F(n) using recursion
  """
  if n == 1: # base case
      return 2

  return 2 * F(n - 1) + n ** 2 # recursive call

# %%
def closed_formula(n):
  """
  Function that calculates the value of F(n) using the closed formula
  """
  # F(n) = 2^n * F(1) + sum of n^2 * 2^(n-k) for k=2 till n
  resultado = 2 ** n * 2  # homogeneous part: 2^n * F(1)
  for k in range(2, n + 1):
    resultado += (k ** 2) * (2 ** (n - k))
  return resultado

# %%
if __name__ == "__main__":

  n = int(input("Type the value of n: "))

  if n < 1:
      print("n must be greater than or equal 1.")
  else:
      recursive_result = F(n)
      closed_result = closed_formula(n)

      print(f"\nF({n}) by recursion = {recursive_result}")
      print(f"F({n}) by closed formula = {closed_result}")
# Out:
# Type the value of n: 500
#
# F(500) by recursion = 21277038951324922155085733029379394489408173299279921131641393892624869676630384606741255600118377021480763446829140461559912167548255054846635429078938
# F(500) by closed formula = 24550429559221064025098922726206993641624815345322985921124685260721003473035059161624525692444281178631650130956700532569129424094140447899963956668314
